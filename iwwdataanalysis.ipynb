# %%
import numpy as pd
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # IWW Data Analysis

# %%
df = pd.read_csv('/Users/hburd/Desktop/IWW Data/zooniverse export_2023.12.csv')

# %%
print(pd.unique(df.user_id).size,
pd.unique(df.user_name).size,
pd.unique(df.user_ip).size,
pd.unique(df.workflow_id).size,
pd.unique(df.workflow_name).size,
pd.unique(df.workflow_version).size,
pd.unique(df.classification_id).size,
pd.unique(df.subject_ids).size)
# Out:
# 3354 5265 3540 2 2 12 491715 91521

# %%
subject_ids_df = df.subject_ids

# %%
print(subject_ids_df)
# Out:
# 0         20848905
# 1         20848892
# 2         20848891
# 3         20848917
# 4         20848893
#             ...
# 491710    86138870
# 491711    86138937
# 491712    86138918
# 491713    86138736
# 491714    86138942
# Name: subject_ids, Length: 491715, dtype: int64

# %%
subject_ids_df.plot()
# Out:
# <Axes: >

# %%
df.plot.scatter(x='subject_ids', y='classification_id')
# Out:
# <Axes: xlabel='subject_ids', ylabel='classification_id'>

# %%
plt.bar(df.subject_ids, (pd.unique(df.user_id).size))
plt.show()
